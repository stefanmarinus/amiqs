# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 100
import numpy as np
import os
dir = os.getcwd()

# %%
ybobs = 8.6*pow(10,-11)

# %%
try:
    lnv = np.loadtxt( dir + '/asym_results_lnv.dat', skiprows= 2)
except:
    pass

try:
    lnc = np.loadtxt( dir + '/asym_results_lnc.dat', skiprows= 2)
except:
    pass

# %%
plt.loglog(lnv.T[0], np.abs(lnv.T[1]) )
# plt.ylim([pow(10,-12), pow(10,-9)])
# plt.xlim(0.1,1)
plt.show()
